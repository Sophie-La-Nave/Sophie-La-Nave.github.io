# %% [markdown]
# *Reffering to lessons starting at 1, despite this not aligning with the course, simply to follow when the coding starts, not the actual lesson number overall.*

# %% [markdown]
# Lessons covered: Intro to Data Frames, Row Selection With Data Frames,

# %% [markdown]
# **Lesson 1**

# %%
import pandas as pd

# %%
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/gpa.csv")

# %%
df
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 0      2024  Winter  2024-wi     ADV     150    Introduction to Advertising
# 1      2024  Winter  2024-wi    AFRO     100   Intro to African American St
# 2      2024  Winter  2024-wi    ASTR     330          Extraterrestrial Life
# 3      2024  Winter  2024-wi    ATMS     120   Severe and Hazardous Weather
# 4      2024  Winter  2024-wi    BADM     275          Operations Management
# ...     ...     ...      ...     ...     ...                            ...
# 69107  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 69108  2010  Summer  2010-su    STAT     440    Statistical Data Management
# 69109  2010  Summer  2010-su     TAM     212          Introductory Dynamics
# 69110  2010  Summer  2010-su     TAM     251   Introductory Solid Mechanics
# 69111  2010  Summer  2010-su     TAM     335   Introductory Fluid Mechanics
#
# ...

# %% [markdown]
# **Lesson 2**

# %%
df_2 = pd.read_csv("https://waf.cs.illinois.edu/discovery/course-catalog.csv")

# %%
df_2[df.Subject == "MCB"]
# Out:
# <ipython-input-9-68b11fbc07d8>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_2[df.Subject == "MCB"]
#        Year    Term YearTerm Subject  Number  \
# 2124   2025  Spring  2025-sp    CHEM     103
# 2125   2025  Spring  2025-sp    CHEM     103
# 2126   2025  Spring  2025-sp    CHEM     103
# 2127   2025  Spring  2025-sp    CHEM     103
# 2128   2025  Spring  2025-sp    CHEM     103
# ...     ...     ...      ...     ...     ...
# 9587   2025  Spring  2025-sp    NEUR     598
# 10253  2025  Spring  2025-sp    PHYS     427
# 10254  2025  Spring  2025-sp    PHYS     427
# 10255  2025  Spring  2025-sp    PHYS     427
# 10256  2025  Spring  2025-sp    PHYS     435
#
#                                     Name  \
# 2124             General Chemistry Lab I
# 2125             General Chemistry Lab I
# 2126             General Chemistry Lab I
# 2127             General Chemistry Lab I
# 2128             General Chemistry Lab I
# ...

# %%
df_2.sample(n = 5)
# Out:
#       Year    Term YearTerm Subject  Number  \
# 3781  2025  Spring  2025-sp     ECE     120
# 1201  2025  Spring  2025-sp    ARTS     444
# 7486  2025  Spring  2025-sp    LING     506
# 6007  2025  Spring  2025-sp      HK     271
# 2933  2025  Spring  2025-sp     CMN     529
#
#                                     Name  \
# 3781           Introduction to Computing
# 1201                      Interaction II
# 7486        Topics in Computational Ling
# 6007  Health Equity in the United States
# 2933        Seminar Communication Theory
#
#                                             Description   Credit Hours  \
# 3781  Introduction to digital logic, computer system...       4 hours.
# 1201  Further exploration of interaction, with an in...  3 OR 4 hours.
# 7486  Provides an introduction to practical problems...       4 hours.
# 6007  Introduces students to the field of health equ...       3 hours.
# 2933  Special topics in communication theory and res...       4 hours.
#
# ...

# %% [markdown]
# **Lesson 3**

# %%
import pandas as pd

# %%
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/berkeley.csv")
df
# Out:
#        Year  Major Gender Admission
# 0      1973      C      F  Rejected
# 1      1973      B      M  Accepted
# 2      1973  Other      F  Accepted
# 3      1973  Other      M  Accepted
# 4      1973  Other      M  Rejected
# ...     ...    ...    ...       ...
# 12758  1973  Other      M  Accepted
# 12759  1973      D      M  Accepted
# 12760  1973  Other      F  Rejected
# 12761  1973  Other      M  Rejected
# 12762  1973  Other      M  Accepted
#
# [12763 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Major').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %% [markdown]
# **Lesson 4**

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/course-catalog.csv")
df[ df["Subject"] == "CHEM" ]  # index notation, using df["Subject"]
# Out:
#       Year    Term YearTerm Subject  Number  \
# 2025  2025  Spring  2025-sp    CHEM     101
# 2026  2025  Spring  2025-sp    CHEM     101
# 2027  2025  Spring  2025-sp    CHEM     101
# 2028  2025  Spring  2025-sp    CHEM     101
# 2029  2025  Spring  2025-sp    CHEM     101
# ...    ...     ...      ...     ...     ...
# 2406  2025  Spring  2025-sp    CHEM     590
# 2407  2025  Spring  2025-sp    CHEM     590
# 2408  2025  Spring  2025-sp    CHEM     593
# 2409  2025  Spring  2025-sp    CHEM     595
# 2410  2025  Spring  2025-sp    CHEM     599
#
#                                                 Name  \
# 2025                          Introductory Chemistry
# 2026                          Introductory Chemistry
# 2027                          Introductory Chemistry
# 2028                          Introductory Chemistry
# 2029                          Introductory Chemistry
# ...                                              ...
# 2406                     Special Topics in Chemistry
# ...

# %% [markdown]
# **Lesson 5**

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/football.csv")
group = df.groupby("Location")
df_mean = group.agg("mean", numeric_only = True).reset_index()
df_mean[ (df_mean.Location == "vs.") | (df_mean.Location == "@") ]
# Out:
#    Location       Season  OpponentRank  IlliniScore  OpponentScore
# 0         @  1965.899065          12.4    16.149533      20.256075
# 25      vs.  1961.979138          14.5    21.309192      16.186630

# %%
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/football.csv")
group = df.groupby("Location")
df_mean = group.agg("mean", numeric_only=True).reset_index()
df_mean
# Out:
#              Location       Season  OpponentRank  IlliniScore  OpponentScore
# 0                   @  1965.899065          12.4    16.149533      20.256075
# 1         Atlanta, GA  1985.000000           NaN    29.000000      31.000000
# 2      Birmingham, AL  1988.000000           NaN    10.000000      14.000000
# 3           Bronx, NY  1938.500000           NaN     0.000000       6.500000
# 4         Chicago, IL  1963.111111           NaN    16.555556      18.444444
# 5       Cleveland, OH  1944.500000           NaN    10.250000      24.000000
# 6          Dallas, TX  2014.000000           NaN    18.000000      35.000000
# 7         Detroit, MI  1953.000000           NaN    11.000000      17.500000
# 8         El Paso, TX  1991.000000           NaN     3.000000       6.000000
# 9         Houston, TX  2010.000000           NaN    38.000000      14.000000
# 10   Indianapolis, IN  1928.333333           NaN    17.333333       2.333333
# ...

# %% [markdown]
# ***Simple Simulations***

# %%
import random
import pandas as pd
data = []                      # Step 1, empty list `data`
for i in range(600):           # Step 2: for-loop
  roll = random.randint(1, 6)  # Step 3: simulate real-world factors
  d = { "roll": roll }         # Step 4: accumulate factors in dictionary `d`
  data.append(d)               # Step 5: append `d` to `data`
df = pd.DataFrame(data)        # Step 6: create the DataFrame (outside of the for-loop)

df
# Out:
#      roll
# 0       6
# 1       1
# 2       1
# 3       4
# 4       5
# ..    ...
# 595     3
# 596     1
# 597     2
# 598     3
# 599     3
#
# [600 rows x 1 columns]

# %% [markdown]
# Pyth. Funccts. Random. Dists.

# %%
from scipy.stats import binom
D = binom(p=0.1, n=50)   # Binomial Distribution with p=0.1, n=50
